# %% [markdown]
# # 04 General Tips Practice
#
# Use this notebook to practice improving prompts with the core design tips.

# %% [markdown]
# ## Learning goals
#
# - Diagnose weak prompts using general design principles
# - Rewrite vague prompts into direct and testable prompts
# - Practice telling the model what to do instead of only what to avoid

# %% [markdown]
# ## Exercise 1: Spot the weakness
#
# Identify the main problem in each prompt.

# %%
prompts = {
    "p1": "Explain prompt engineering. Keep it short and not too descriptive.",
    "p2": "Do not ask for user preferences. Do not ask for personal details.",
    "p3": "Analyze this product review, classify sentiment, extract product issues, suggest a marketing plan, and rewrite it for executives.",
}

diagnosis = {
    "p1": "",
    "p2": "",
    "p3": "",
}
diagnosis

# %% [markdown]
# ## Exercise 2: Rewrite the prompt
#
# Rewrite each prompt so it becomes more direct, specific, and testable.

# %%
rewrites = {
    "p1": "",
    "p2": "",
    "p3": "",
}
rewrites

# %% [markdown]
# ## Exercise 3: Add a fallback behavior
#
# Take a prompt that may fail and define what the model should do when the needed information is missing.

# %%
fallback_prompt = "Recommend a movie to the user from today's top trending films."

improved_with_fallback = """"""
print(improved_with_fallback)

# %% [markdown]
# ## Quick check
#
# 1. What does 'start simple' protect you from?
# 2. Why is 'a few sentences' weaker than '2-3 sentences'?
# 3. Why is 'do X' usually stronger than 'do not do Y'?
# 4. When does prompt splitting become a better strategy than adding more text?
