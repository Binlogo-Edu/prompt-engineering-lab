# %% [markdown]
# # 03 Prompt Elements Practice
#
# Use this notebook to identify and design prompt elements on purpose.

# %% [markdown]
# ## Learning goals
#
# - Identify instruction, context, input data, and output indicator
# - Rewrite weak prompts into structured prompts
# - Build the habit of debugging prompts by element

# %% [markdown]
# ## Exercise 1: Label the elements
#
# For each prompt, write which parts are instruction, context, input data, and output indicator.

# %%
prompt_1 = """
Classify the text into neutral, negative, or positive.

Text: I think the food was okay.

Sentiment:
"""

prompt_2 = """
You are helping a support team. Use a friendly and concise tone.
Summarize the ticket in 2 bullet points.

Ticket: The login page keeps refreshing after I enter my password.

Summary:
"""

my_labels = {
    "prompt_1": {"instruction": "", "context": "", "input_data": "", "output_indicator": ""},
    "prompt_2": {"instruction": "", "context": "", "input_data": "", "output_indicator": ""},
}
my_labels

# %% [markdown]
# ## Exercise 2: Strengthen the prompt
#
# Take the weak prompt below and rewrite it using explicit elements.

# %%
weak_prompt = "Tell me about this review: The battery life is short but the screen is great."

rewritten_prompt = """"""
print(rewritten_prompt)

# %% [markdown]
# ## Exercise 3: Failure diagnosis
#
# Suppose the model keeps returning long paragraphs when you only want a label.
# Which prompt element is most likely too weak, and how would you fix it?

# %%
diagnosis = {
    "weakest_element": "",
    "fix": "",
}
diagnosis

# %% [markdown]
# ## Quick check
#
# 1. Which element defines the task?
# 2. Which element provides background information?
# 3. Which element contains the actual content to operate on?
# 4. Which element most directly controls the response format?
