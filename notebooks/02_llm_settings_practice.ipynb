# %% [markdown]
# # 02 LLM Settings Practice
#
# Use this notebook to build intuition for how model settings shape output.

# %% [markdown]
# ## Learning goals
#
# - Explain what each core setting changes
# - Predict how outputs vary when settings change
# - Practice changing one variable at a time

# %% [markdown]
# ## Exercise 1: Task-to-setting mapping
#
# Fill in which setting you would tune first for each task.

# %%
tasks = {
    "fixed_json_extraction": "",
    "creative_taglines": "",
    "response_too_long": "",
    "need_generation_to_stop_at_marker": "",
}
tasks

# %% [markdown]
# ## Exercise 2: Predict the effect
#
# Write your prediction before testing.

# %%
predictions = {
    "lower_temperature": "",
    "higher_temperature": "",
    "lower_top_p": "",
    "lower_max_tokens": "",
    "adding_stop_sequence": "",
}
predictions

# %% [markdown]
# ## Exercise 3: Controlled experiment plan
#
# Design a simple experiment: one task, one prompt, one setting changed at a time.

# %%
experiment_plan = {
    "task": "",
    "prompt": "",
    "baseline_settings": {},
    "single_variable_to_change": "",
    "evaluation_rubric": ["consistency", "format accuracy", "usefulness"],
}
experiment_plan
