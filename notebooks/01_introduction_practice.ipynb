# %% [markdown]
# # 01 Introduction Practice
#
# Use this notebook to turn the Introduction chapter into active recall and small experiments.

# %% [markdown]
# ## Learning goals
#
# - Explain what prompt engineering is in your own words
# - Distinguish `temperature` from `top_p`
# - Build the habit of testing prompts experimentally

# %% [markdown]
# ## Exercise 1: Feynman explanation
#
# Write a 2-3 sentence explanation of prompt engineering as if you were teaching a beginner.

# %%
my_definition = """"""
print(my_definition)

# %% [markdown]
# ## Exercise 2: Compare parameters
#
# Fill the table from memory before checking your notes.

# %%
comparison = {
    "temperature": "",
    "top_p": "",
    "when_to_lower_temperature": "",
    "why_top_p_1_is_a_neutral_default": "",
}
comparison

# %% [markdown]
# ## Exercise 3: Experimental mindset
#
# Pick one simple prompt, then predict how output quality may change when:
#
# - model changes
# - `temperature` changes
# - `top_p` changes

# %%
prompt = "Explain recursion to a 12-year-old in 3 bullet points."

predictions = {
    "model_change": "",
    "temperature_change": "",
    "top_p_change": "",
}

prompt, predictions

# %% [markdown]
# ## Optional API experiment
#
# If your environment is configured, run the same prompt with different settings and compare outputs for consistency and creativity.

# %%
# Optional: adapt this if you have an API key configured.
# from openai import OpenAI
# client = OpenAI()
#
# def run_prompt(prompt, model="gpt-3.5-turbo", temperature=1, top_p=1):
#     response = client.chat.completions.create(
#         model=model,
#         temperature=temperature,
#         top_p=top_p,
#         messages=[{"role": "user", "content": prompt}],
#     )
#     return response.choices[0].message.content
#
# test_prompt = "Give me three taglines for a coffee shop."
# print(run_prompt(test_prompt, temperature=0.2, top_p=1))
# print(run_prompt(test_prompt, temperature=1.0, top_p=1))

# %% [markdown]
# ## Check yourself
#
# Answer before moving on:
#
# 1. Why is prompt engineering systematic rather than purely intuitive?
# 2. What does lowering `temperature` usually do?
# 3. What does keeping `top_p=1` usually imply?
# 4. Why should the same prompt be tested more than once?
