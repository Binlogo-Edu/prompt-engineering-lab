# %% [markdown]
# # 05 Zero-Shot Practice
#
# Use this notebook to build intuition for zero-shot prompting as a starting baseline.

# %% [markdown]
# ## Learning goals
#
# - Explain what zero-shot prompting is
# - Identify whether a prompt is zero-shot or not
# - Decide when zero-shot is enough and when to move to few-shot

# %% [markdown]
# ## Exercise 1: Is it zero-shot?
#
# Label each prompt as zero-shot or not zero-shot.

# %%
prompts = {
    "p1": "Classify the text into neutral, negative or positive. Text: The food was okay. Sentiment:",
    "p2": "Classify the text into neutral, negative or positive. Text: The trip was okay. Sentiment: neutral. Text: The food was okay. Sentiment:",
    "p3": "Translate the sentence to Chinese. Sentence: Hello.",
    "p4": "Answer using only the context below. If unsure, say Unsure about answer. Context: ... Question: ... Answer:",
}

labels = {
    "p1": "",
    "p2": "",
    "p3": "",
    "p4": "",
}
labels

# %% [markdown]
# ## Exercise 2: Decide the next move
#
# For each task, decide whether zero-shot is a good first attempt or whether few-shot is likely needed soon.

# %%
tasks = {
    "simple_sentiment": "",
    "strict_custom_json_schema": "",
    "unusual_label_names": "",
    "short_translation": "",
    "domain_specific_legal_extraction": "",
}
tasks

# %% [markdown]
# ## Exercise 3: Improve a zero-shot prompt
#
# Strengthen the prompt without adding examples.

# %%
weak_prompt = "Summarize this article."

improved_zero_shot_prompt = """"""
print(improved_zero_shot_prompt)

# %% [markdown]
# ## Quick check
#
# 1. Does zero-shot mean no instruction?
# 2. Does adding an output format make a prompt no longer zero-shot?
# 3. What is the main signal that you should try few-shot next?
# 4. Why is zero-shot a good baseline?
